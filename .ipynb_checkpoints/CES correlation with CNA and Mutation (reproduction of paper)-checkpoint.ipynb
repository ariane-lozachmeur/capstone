# %%
import pandas as pd
import numpy as np
from math import *
import matplotlib.pyplot as plt
import matplotlib
import matplotlib
import scipy.stats

# %%
def load_data(expression_file, mutation_file):
    expr = pd.read_table(expression_file)
    mut = pd.read_table(mutation_file)
    ces = expr.sum()[2:]
    data = mut[['Sample ID','CNA','Mutation Count']].merge(pd.DataFrame(ces,columns=['ces']),
                                                           how='inner',left_on='Sample ID',right_index=True)
    return data

def show_plots(data):
    plt.scatter(data['ces'], data['Mutation Count'])
    plt.ylabel('Mutation Count')
    plt.xlabel('CES')
    plt.title('Mutation and CES corralation')
    plt.show()
    print('CES and Mutation Spearman pvalue: ')
    data_nona = data[['ces','Mutation Count']].dropna()
    print(scipy.stats.spearmanr(data_nona['ces'],data_nona['Mutation Count']))

    plt.scatter(data['ces'], data['CNA'])
    plt.ylabel('CNA')
    plt.xlabel('CES')
    plt.title('CNA and CES corralation')
    plt.show()
    print('CES and CNA Sperrman pvalue: ')
    data_nona = data[['ces','CNA']].dropna()
    print(scipy.stats.spearmanr(data_nona['ces'],data_nona['CNA']))
    
def boxplot(column1, column2='ces', ylim=None):
    tmp = df[[column1, column2]].dropna()
    low_q = np.percentile(tmp[column2],25)
    high_q = np.percentile(tmp[column2],75)
    low = tmp[tmp[column2]<low_q]
    high = tmp[tmp[column2]>high_q]
    plt.boxplot([low[column1].dropna(),high[column1].dropna()], labels = ['Low CES','High CES'])
    if ylim:
        plt.ylim(ylim)
#     plt.title(str(column1)+' for low and high '+column2+' tumors')
    plt.ylabel('Mutation Count')
    print('Pvalue of t-test on high and low: ', scipy.stats.mannwhitneyu(low[column1], high[column1]))
    plt.show()

# %% [markdown]
# # Adrenocortical carcinoma

# %%
data = load_data('data/adrenocortical/ces_expr.txt','data/adrenocortical/mutation_cna.txt')
show_plots(data)
# Out:
# CES and Mutation Spearman pvalue:
# SpearmanrResult(correlation=0.47097073988699079, pvalue=2.0042482557929822e-05)
# CES and CNA Sperrman pvalue:
# SpearmanrResult(correlation=0.11152204836415362, pvalue=0.34081135771339854)

# %%
df = data
plt.figure()
boxplot('Mutation Count', ylim=(0,300))
boxplot('CNA')
# Out:
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=989.0, pvalue=7.4237173799268201e-11)
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=2702.0, pvalue=1.6962730220600661e-22)

# %% [markdown]
# # Bladder carcinoma

# %%
data = load_data('data/bladder_carcinoma/cBioPortal_data.txt','data/bladder_carcinoma/Mutation Count vs. CNA.txt')
show_plots(data)
# Out:
# CES and Mutation Spearman pvalue:
# SpearmanrResult(correlation=0.27030540066515235, pvalue=0.001947784702980861)
# CES and CNA Sperrman pvalue:
# SpearmanrResult(correlation=0.30709812089562971, pvalue=2.8541119432150686e-10)

# %%
df = data
boxplot('Mutation Count', ylim=(0,500))
# Out:
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=270.5, pvalue=0.00060581241426431215)

# %% [markdown]
# # Breast Adenocarcinoma

# %%
data = load_data('data/breast_adenomcarcinoma/cBioPortal_data.txt','data/breast_adenomcarcinoma/Mutation Count vs. CNA.txt')
show_plots(data)
# Out:
# CES and Mutation Spearman pvalue:
# SpearmanrResult(correlation=0.4436007373366308, pvalue=1.8592198904806618e-48)
# CES and CNA Sperrman pvalue:
# SpearmanrResult(correlation=0.5512080096141927, pvalue=5.1176512039600788e-87)

# %%
df = data
boxplot('Mutation Count', ylim=(0,200))
# Out:
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=11215.5, pvalue=1.8683918906695735e-33)

# %% [markdown]
# # Cervial SCC

# %%
data = load_data('data/cervical_SCC/cBioPortal_data.txt','data/cervical_SCC/Mutation Count vs. CNA.txt')
show_plots(data)
# Out:
# CES and Mutation Spearman pvalue:
# SpearmanrResult(correlation=0.096438983103396395, pvalue=0.18214426893370661)
# CES and CNA Sperrman pvalue:
# SpearmanrResult(correlation=0.17734619502917731, pvalue=0.0022722433668425912)

# %%
df = data
boxplot('Mutation Count', ylim=(0,300))
# Out:
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=988.5, pvalue=0.11611887329139919)

# %% [markdown]
# # Glioblastoma

# %%
data = load_data('data/glioblastoma/cBioPortal_data.txt','data/glioblastoma/Mutation Count vs. CNA.txt')
show_plots(data)
# Out:
# CES and Mutation Spearman pvalue:
# SpearmanrResult(correlation=-0.041360065446545621, pvalue=0.59899865424419674)
# CES and CNA Sperrman pvalue:
# SpearmanrResult(correlation=0.19490572172502149, pvalue=0.00012364209055647953)

# %%
df = data
boxplot('Mutation Count', ylim=(0,100))
# Out:
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=796.0, pvalue=0.34153530654080699)

# %% [markdown]
# # Kidney RCC

# %%
data = load_data('data/kidney RCC/cBioPortal_data.txt','data/kidney RCC/Mutation Count vs. CNA.txt')
show_plots(data)
# Out:
# CES and Mutation Spearman pvalue:
# SpearmanrResult(correlation=0.08441744697517635, pvalue=0.073941006712691326)
# CES and CNA Sperrman pvalue:
# SpearmanrResult(correlation=0.22159902415874189, pvalue=2.8337476676823957e-07)

# %%
df = data
boxplot('Mutation Count', ylim=(0,100))
# Out:
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=5686.0, pvalue=0.11360998689539359)

# %% [markdown]
# # Kidney RPC

# %%
data = load_data('data/kidney_RPC/cBioPortal_data.txt','data/kidney_RPC/Mutation Count vs. CNA.txt')
show_plots(data)
# Out:
# CES and Mutation Spearman pvalue:
# SpearmanrResult(correlation=0.042598472189658579, pvalue=0.47694767207859912)
# CES and CNA Sperrman pvalue:
# SpearmanrResult(correlation=0.15095507356457649, pvalue=0.010306626650427673)

# %%
df = data
boxplot('Mutation Count', ylim=(0,100))
# Out:
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=2431.5, pvalue=0.47009582010909762)

# %% [markdown]
# # Lower grade glioma

# %%
data = load_data('data/lower_grade_glioma/cBioPortal_data.txt','data/lower_grade_glioma/Mutation Count vs. CNA.txt')
show_plots(data)
# Out:
# CES and Mutation Spearman pvalue:
# SpearmanrResult(correlation=0.39220098131402864, pvalue=5.9291986438342412e-12)
# CES and CNA Sperrman pvalue:
# SpearmanrResult(correlation=0.47791034893490869, pvalue=1.9965244410708452e-31)

# %%
df = data
boxplot('Mutation Count', ylim=(0,70))
# Out:
# Pvalue of t-test on high and low:  MannwhitneyuResult(statistic=989.0, pvalue=7.4237173799268201e-11)
