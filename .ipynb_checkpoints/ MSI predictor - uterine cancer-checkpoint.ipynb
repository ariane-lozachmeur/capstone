# %%
import pandas as pd
import numpy as np
from math import *
import matplotlib.pyplot as plt
import matplotlib
import matplotlib
import scipy.stats

# %%
def load_ces(file):
    df_ces = pd.read_table(file)
    ces = df_ces.sum()[2:]
    return pd.DataFrame(ces,columns=['ces'])

def load_data(file, cat=None):    
    df = pd.read_table(file)
    patients = df['COMMON']
    df = df.transpose()[2:]
    df.columns = [s + '_' +cat for s in patients]
    return df

def load_mutation(file):
    df = pd.read_table(file)[['Sample ID', 'Mutation Count', 'CNA']]
    return df

# %%
genes = list(pd.read_table('data/stomach/stomach_mmr.txt')['COMMON'])
genes
# Out:
# ['MLH1', 'MLH3', 'MSH2', 'MSH3', 'MSH6', 'PCNA', 'PMS2', 'RFC1']

# %%
df1 = load_data('data/stomach/stomach_mrr_methylation.txt', cat='meth')
df1.head()
# Out:
#                  MLH1_meth  MLH3_meth  MSH2_meth  MSH3_meth  MSH6_meth  \
# TCGA-BR-8370-01  0.0228193  0.0320085  0.0318651   0.103415  0.0212566
# TCGA-D7-6521-01  0.0204145  0.0614712  0.0239722  0.0875652  0.0225079
# TCGA-KB-A6F7-01  0.0207573   0.050202  0.0190618  0.0822726  0.0205524
# TCGA-BR-4294-01        NaN        NaN        NaN        NaN        NaN
# TCGA-BR-4271-01        NaN        NaN        NaN        NaN        NaN
#
#                  PCNA_meth  PMS2_meth  RFC1_meth
# TCGA-BR-8370-01  0.0433578  0.0175772  0.0219151
# TCGA-D7-6521-01  0.0323054  0.0216822  0.0223222
# TCGA-KB-A6F7-01  0.0354551  0.0198874  0.0198977
# TCGA-BR-4294-01        NaN        NaN        NaN
# TCGA-BR-4271-01        NaN        NaN        NaN

# %%
df2 = load_ces('data/stomach/stomach_ces.txt')
df2.head()
# Out:
#                      ces
# TCGA-D7-6521-01   -8.777
# TCGA-KB-A6F7-01   6.9997
# TCGA-BR-4294-01  -20.525
# TCGA-VQ-A94U-01  -7.0348
# TCGA-CG-5725-01  15.4856

# %%
df3 = load_data('data/stomach/stomach_mmr.txt', cat='expr')
df3.head()
# Out:
#                 MLH1_expr MLH3_expr MSH2_expr MSH3_expr MSH6_expr PCNA_expr  \
# TCGA-D7-6521-01   -0.5502   -1.3668   -0.8963   -0.9451   -0.7098   -1.0002
# TCGA-KB-A6F7-01    0.2019   -0.9223    0.4534   -1.4675     1.513    1.3693
# TCGA-BR-4294-01      3.24   -0.9735    -0.735    1.1141    1.5381   -0.6328
# TCGA-VQ-A94U-01   -0.3783    2.0368    1.5879    1.7373    0.9699    0.0618
# TCGA-CG-5725-01    1.7241   -1.5041    2.7026   -0.8315    1.6831   -0.4386
#
#                 PMS2_expr RFC1_expr
# TCGA-D7-6521-01   -0.3132    -1.341
# TCGA-KB-A6F7-01    0.1093   -1.5263
# TCGA-BR-4294-01    0.4227   -0.2502
# TCGA-VQ-A94U-01    3.4877   -0.5686
# TCGA-CG-5725-01    4.7108    0.0198

# %%
df4 = load_data('data/stomach/stomach_mmr_mutation.txt', cat='mut')
df4.head()
# Out:
#                 MLH1_mut MLH3_mut MSH2_mut MSH3_mut MSH6_mut PCNA_mut  \
# TCGA-BR-8370-01      NaN      NaN      NaN      NaN      NaN      NaN
# TCGA-D7-6521-01      NaN      NaN      NaN      NaN      NaN      NaN
# TCGA-KB-A6F7-01      NaN      NaN      NaN      NaN      NaN      NaN
# TCGA-BR-4294-01      NaN      NaN      NaN      NaN      NaN      NaN
# TCGA-CG-5725-01      NaN      NaN      NaN      NaN      NaN      NaN
#
#                 PMS2_mut RFC1_mut
# TCGA-BR-8370-01      NaN      NaN
# TCGA-D7-6521-01      NaN      NaN
# TCGA-KB-A6F7-01      NaN      NaN
# TCGA-BR-4294-01      NaN      NaN
# TCGA-CG-5725-01      NaN      NaN

# %%
df5 = load_mutation('data/stomach/stomach.txt')
df5.head()
# Out:
#          Sample ID  Mutation Count       CNA
# 0  TCGA-BR-6452-01          6545.0  0.050651
# 1  TCGA-BR-6453-01           165.0  0.049998
# 2  TCGA-BR-6454-01           123.0  0.181488
# 3  TCGA-BR-6455-01            77.0  0.117506
# 4  TCGA-BR-6456-01            35.0  0.386722

# %%
df = df5.merge(df1, left_on='Sample ID', right_index=True)
df = df.merge(df2, left_on='Sample ID', right_index=True)
df = df.merge(df3, left_on='Sample ID', right_index=True)
df = df.merge(df4, left_on='Sample ID', right_index=True)
df.head()
# Out:
#          Sample ID  Mutation Count       CNA  MLH1_meth  MLH3_meth  MSH2_meth  \
# 0  TCGA-BR-6452-01          6545.0  0.050651    0.48308   0.042466  0.0222332
# 1  TCGA-BR-6453-01           165.0  0.049998  0.0218543  0.0565447  0.0195032
# 2  TCGA-BR-6454-01           123.0  0.181488   0.019822  0.0490996  0.0166467
# 3  TCGA-BR-6455-01            77.0  0.117506  0.0229177  0.0517937  0.0169772
# 4  TCGA-BR-6456-01            35.0  0.386722  0.0221793  0.0509518  0.0239083
#
#    MSH3_meth  MSH6_meth  PCNA_meth  PMS2_meth   ...    PMS2_expr RFC1_expr  \
# 0  0.0871269  0.0232892  0.0351302  0.0213428   ...      -0.0119   -0.1223
# 1  0.0833771  0.0199644  0.0489193  0.0275883   ...      -0.5476   -0.9475
# 2  0.0768036  0.0211339  0.0418918  0.0199929   ...      -0.3026   -2.0006
# 3  0.0921804  0.0194734  0.0489449  0.0217387   ...      -0.0281   -0.1027
# 4  0.0884377  0.0239651   0.041369  0.0157891   ...       0.0939   -1.4068
#
#   MLH1_mut MLH3_mut MSH2_mut MSH3_mut MSH6_mut PCNA_mut PMS2_mut RFC1_mut
# 0      NaN    M181I      NaN      NaN      NaN      NaN      NaN    V976A
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# # MSI status in function of gene expression

# %% [markdown]
# If the tumor is is in the lower 5% for one gene expression, it is labelled as MSI.

# %%
df['msi_status'] = np.zeros(len(df))
for g in genes:
    limit = df[g+'_expr'].quantile(0.05)
    for ix in df[df[g+'_expr']<limit]['msi_status'].index:
        df = df.set_value(ix,'msi_status',1)
    
df.head()
# Out:
#          Sample ID  Mutation Count       CNA  MLH1_meth  MLH3_meth  MSH2_meth  \
# 0  TCGA-BR-6452-01          6545.0  0.050651    0.48308   0.042466  0.0222332
# 1  TCGA-BR-6453-01           165.0  0.049998  0.0218543  0.0565447  0.0195032
# 2  TCGA-BR-6454-01           123.0  0.181488   0.019822  0.0490996  0.0166467
# 3  TCGA-BR-6455-01            77.0  0.117506  0.0229177  0.0517937  0.0169772
# 4  TCGA-BR-6456-01            35.0  0.386722  0.0221793  0.0509518  0.0239083
#
#    MSH3_meth  MSH6_meth  PCNA_meth  PMS2_meth    ...     RFC1_expr MLH1_mut  \
# 0  0.0871269  0.0232892  0.0351302  0.0213428    ...       -0.1223      NaN
# 1  0.0833771  0.0199644  0.0489193  0.0275883    ...       -0.9475      NaN
# 2  0.0768036  0.0211339  0.0418918  0.0199929    ...       -2.0006      NaN
# 3  0.0921804  0.0194734  0.0489449  0.0217387    ...       -0.1027      NaN
# 4  0.0884377  0.0239651   0.041369  0.0157891    ...       -1.4068      NaN
#
#   MLH3_mut MSH2_mut MSH3_mut MSH6_mut PCNA_mut PMS2_mut RFC1_mut msi_status
# 0    M181I      NaN      NaN      NaN      NaN      NaN    V976A        0.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN        0.0
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN        1.0
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN        0.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN        0.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # MSI status in function of mutation

# %% [markdown]
# If one the the gene in the pathway is mutated, the tumor is classified as MSI.

# %%
for g in genes:
    no_mutations = pd.isnull(df[g+'_mut'])
    for ix in no_mutations[no_mutations==False].index:
        df = df.set_value(ix,'msi_status',1)
df.head()
# Out:
#          Sample ID  Mutation Count       CNA  MLH1_meth  MLH3_meth  MSH2_meth  \
# 0  TCGA-BR-6452-01          6545.0  0.050651    0.48308   0.042466  0.0222332
# 1  TCGA-BR-6453-01           165.0  0.049998  0.0218543  0.0565447  0.0195032
# 2  TCGA-BR-6454-01           123.0  0.181488   0.019822  0.0490996  0.0166467
# 3  TCGA-BR-6455-01            77.0  0.117506  0.0229177  0.0517937  0.0169772
# 4  TCGA-BR-6456-01            35.0  0.386722  0.0221793  0.0509518  0.0239083
#
#    MSH3_meth  MSH6_meth  PCNA_meth  PMS2_meth    ...     RFC1_expr MLH1_mut  \
# 0  0.0871269  0.0232892  0.0351302  0.0213428    ...       -0.1223      NaN
# 1  0.0833771  0.0199644  0.0489193  0.0275883    ...       -0.9475      NaN
# 2  0.0768036  0.0211339  0.0418918  0.0199929    ...       -2.0006      NaN
# 3  0.0921804  0.0194734  0.0489449  0.0217387    ...       -0.1027      NaN
# 4  0.0884377  0.0239651   0.041369  0.0157891    ...       -1.4068      NaN
#
#   MLH3_mut MSH2_mut MSH3_mut MSH6_mut PCNA_mut PMS2_mut RFC1_mut msi_status
# 0    M181I      NaN      NaN      NaN      NaN      NaN    V976A        1.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN        0.0
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN        1.0
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN        0.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN        0.0
#
# [5 rows x 29 columns]

# %%
plt.scatter(df['ces'],df['Mutation Count'],c=df['msi_status'],cmap=plt.cm.Set1,marker='o')
plt.xlabel('CES')
plt.ylabel('Mutation Count')
plt.show()

# %%
plt.scatter(df['ces'],df['Mutation Count'],c=df['msi_status'],cmap=plt.cm.Set1,marker='o')
plt.xlabel('CES')
plt.ylim(0,400)
plt.ylabel('Mutation Count')
plt.show()

# %%
plt.scatter(df['ces'],df['CNA'],c=df['msi_status'],cmap=plt.cm.Set1,marker='o')
plt.xlabel('CES')
plt.ylabel('CNA')
plt.show()
